# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitisrigirkala/Python/blob/main/Patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#printing numbers
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i+1):
    print(j+1, end="")
  print( )
# Out:
# enter the number of row6
# 1
# 12
# 123
# 1234
# 12345
# 123456

# %%
#printing Alaphabet
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i+1):
    print(chr(j+65), end="")
  print( )
# Out:
# enter the number of row5
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
#increasing triangle pattern
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i+1):
    print("*", end="")
  print( )
# Out:
# enter the number of row5
# *
# **
# ***
# ****
# *****

# %%
#printing star
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i+1):
    print("*", end="")
  print( )

# %%
#printing square
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(rows):
    print("*", end="")
  print( )
# Out:
# enter the number of row5
# *****
# *****
# *****
# *****
# *****

# %%
#reversing my star patterns
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i,rows):
    print("*", end="")
  print( )
# Out:
# enter the number of row6
# ******
# *****
# ****
# ***
# **
# *

# %%
#right angle triangle

rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i,rows):
    print(" ", end="")
  for j in range(i+1):
    print("*", end="")
  print( )
# Out:
# enter the number of row3
#    *
#   **
#  ***

# %%
#reverse right angle triangle

rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i+1):
    print(" ", end=" ")
  for j in range(i,rows):
    print("*", end=" ")
  print()
# Out:
# enter the number of row3
#   * * *
#     * *
#       *

# %%
#pyramid pattern
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i,rows):
    print(" ", end="")
  for j in range(i):
    print("*", end="")
  for j in range(i+1):
    print("*", end="")
  print()
# Out:
# enter the number of row4
#     *
#    ***
#   *****
#  *******

# %%
#reverse pyramid
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(i):
    print(" ", end="")
  for j in range(i,rows-1):
    print("*", end="")
  for j in range(i,rows):
    print("*", end="")
  print()
# Out:
# enter the number of row5
# *********
#  *******
#   *****
#    ***
#     *

# %%
#Square pattern bar patter
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(rows):
    if i==0 or i==rows-1 or j==0 or j==rows-1:
      print("*", end="")
    else:
      print(" ", end="")
  print( )
# Out:
# enter the number of row5
# *****
# *   *
# *   *
# *   *
# *****

# %%
#Square plus pattern
rows = int(input("enter the number of row"))

for i in range(rows):
  for j in range(rows):
    if i==rows//2 or j==rows//2:
      print("*", end="")
    else:
      print(" ", end="")
  print( )
# Out:
# enter the number of row6
#    *
#    *
#    *
# ******
#    *
#    *

# %%
#Diamond Pattern
rows = int(input("enter the number of row"))

for i in range(rows-1):
  for j in range(i,rows):
    print(" ", end="")
  for j in range(i):
    print("*", end="")
  for j in range(i+1):
    print("*", end="")
  print()
for i in range(rows):
  for j in range(i+1):
    print(" ", end="")
  for j in range(i,rows-1):
    print("*", end="")
  for j in range(i,rows):
    print("*", end="")
  print()
# Out:
# enter the number of row5
#      *
#     ***
#    *****
#   *******
#  *********
#   *******
#    *****
#     ***
#      *

# %%
#reversing my numbers patterns
rows = int(input("enter the number of row"))

for i in range(rows,0,-1):
  for j in range(i):
    print(j+1, end="")
  print( )
# Out:
# enter the number of row6
# 123456
# 12345
# 1234
# 123
# 12
# 1

# %%
#reversing my numbers patterns
#chr() function is used to convert an integer representing a Unicode code point into its corresponding character
rows = int(input("enter the number of row"))

for i in range(rows,0,-1):
  for j in range(i):
    print(chr(j+65), end="")
  print( )
# Out:
# enter the number of row5
# ABCDE
# ABCD
# ABC
# AB
# A

# %%
#printing floyd's triangle
nums = 1

for i in range(1,7):
  for j in range(i):
    print(nums, end="")
    nums+=1
  print( )
# Out:
# 1
# 23
# 456
# 78910
# 1112131415
# 161718192021

# %%
# for i in range(1,5):
#   for j in range(i):
#     i-=1
#     print(i+1, end="")
#   print( )
for i in range(1,6):
  for j in range(i,0,-1):
    print(j, end="")
  print( )
# Out:
# 1
# 21
# 321
# 4321
# 54321

# %%
for i in range(1,6):
  for j in range(i,0,-1):
    print(i, end="")
  print( )
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i*2, end="")
  print( )
# Out:
# 22222
# 44444
# 66666
# 88888
# 1010101010

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i, end="")
  print( )
# Out:
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
#countdown square
for i in range(4):
  for j in range(4,0,-1):
    print(j, end="")
  print( )
# Out:
# 4321
# 4321
# 4321
# 4321

# %%
for i in range(1,6):
  for j in range(5):
    if i%2==0:
      print(0,end="")
    else:
      print(1,end="")
  print()
# Out:
# 11111
# 00000
# 11111
# 00000
# 11111

# %%
for i in range(1,6):
  for j in range(i,i+4):
    print(j,end=" ")
  print()
# Out:
# 1 2 3 4
# 2 3 4 5
# 3 4 5 6
# 4 5 6 7
# 5 6 7 8
